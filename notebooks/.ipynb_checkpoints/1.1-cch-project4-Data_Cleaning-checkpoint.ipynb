# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 4: Web Scraping Job Postings

# %% [markdown]
# Detailed instructions are in Readme.md
# My answers for this Project are split into several notebooks to make it easier to review key sections and make changes where needed. In 1.1, I work on cleaning the jobs data and EDA.
#
# # NOTE:
# I have less than 1,000 listings. But most of the data, taken from a Government website, has the salary range, which is critical to the analysis. I have also used 20 different search items while scrapping for the listings and don't think it is wise to blindly broaden the search parameters further for the sake of fulfilling the the 1,000 listings criteria.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. DATA CLEANING OF JOBS DATA

# %%
jobs = pd.read_csv('../data/jobs.csv')

# %%
jobs = jobs.drop(columns = 'Unnamed: 0')

# %%
jobs.head()
# Out:
#                                   Company                               Title  \
# 0  HITACHI CONSULTING SINGAPORE PTE. LTD.  Senior Consultant (Data Scientist)
# 1            TRAVELOKA SERVICES PTE. LTD.                   Data Science Lead
# 2            TRAVELOKA SERVICES PTE. LTD.         Senior Level Data Scientist
# 3            TRAVELOKA SERVICES PTE. LTD.   Mid - Senior Level Data Scientist
# 4            TRAVELOKA SERVICES PTE. LTD.            Mid Level Data Scientist
#
#        Salary_Range                                   Responsibilities  \
# 0    $6,000to$9,000  Roles & Responsibilities Problem solver with c...
# 1  $10,000to$15,000  Roles & ResponsibilitiesAs a Data scientist, y...
# 2   $8,300to$15,000  Roles & ResponsibilitiesJob Description As a D...
# 3   $6,100to$10,700  Roles & ResponsibilitiesAs a Data scientist, y...
# 4    $4,300to$7,600  Roles & ResponsibilitiesAs a Data scientist, y...
#
#                                         Requirements         Seniority  \
# 0  Requirements Sound knowledge of machine learni...  Senior Executive
# 1  RequirementsWe are looking for someone with:  ...           Manager
# 2  Requirements  Solid programming skills and und...         Executive
# 3  Requirements  Solid programming skills and und...         Executive
# 4  Requirements  Solid programming skills and und...         Executive
#
#        Employment_Type                Category  \
# 0  Permanent, Contract  Information Technology
# 1            Full Time  Information Technology
# 2            Permanent  Information Technology
# 3            Permanent  Information Technology
# 4            Permanent  Information Technology
#
#                                              Address
# 0  PLAZA 8 @ CBP, 1 CHANGI BUSINESS PARK CRESCENT...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# #### On inspection, it appears 42 rows are completely empty due to dead links. Let's drop those.

# %%
jobs = jobs.dropna(axis=0, how='all')

# %%
jobs.shape
# Out:
# (932, 9)

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 974
# Data columns (total 9 columns):
# Company             932 non-null object
# Title               932 non-null object
# Salary_Range        875 non-null object
# Responsibilities    932 non-null object
# Requirements        932 non-null object
# Seniority           932 non-null object
# Employment_Type     932 non-null object
# Category            932 non-null object
# Address             729 non-null object
# dtypes: object(9)
# memory usage: 72.8+ KB

# %%
jobs.isnull().sum()
# Out:
# Company               0
# Title                 0
# Salary_Range         57
# Responsibilities      0
# Requirements          0
# Seniority             0
# Employment_Type       0
# Category              0
# Address             203
# dtype: int64

# %%
# Replacing the missing addresses with "Undisclosed"
jobs['Address'] = jobs['Address'].fillna('Undisclosed')

# %% [markdown]
# #### 1.1 MINOR FEATURE ENGINGEERING TO SPLIT SALARY INTO LOW AND HIGH RANGE

# %%
salary_high_low = jobs['Salary_Range'].str.split('to', 1, expand=True)

# %%
salary_high_low.columns = ['Salary_Min', 'Salary_Max']

# %%
jobs = pd.concat([jobs, salary_high_low], axis = 'columns')

# %%
jobs = jobs.drop(columns = 'Salary_Range')

# %%
# Removing $ and comma from the salary columns
jobs['Salary_Min'] = jobs['Salary_Min'].map(lambda x : str(x).replace('$',''))
jobs['Salary_Max'] = jobs['Salary_Max'].map(lambda x : str(x).replace('$',''))
jobs['Salary_Min'] = jobs['Salary_Min'].map(lambda x : str(x).replace(',',''))
jobs['Salary_Max'] = jobs['Salary_Max'].map(lambda x : str(x).replace(',',''))

# %%
# Converting salary cols to numeric dtype
jobs['Salary_Min'] = pd.to_numeric(jobs['Salary_Min'], errors='coerce')
jobs['Salary_Max'] = pd.to_numeric(jobs['Salary_Max'], errors='coerce')

# %% [markdown]
# #### 1.2 ADJUSTING SOME SALARY FIGURES AND IMPUTING MISSING SALARIES

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932 entries, 0 to 974
# Data columns (total 10 columns):
# Company             932 non-null object
# Title               932 non-null object
# Responsibilities    932 non-null object
# Requirements        932 non-null object
# Seniority           932 non-null object
# Employment_Type     932 non-null object
# Category            932 non-null object
# Address             932 non-null object
# Salary_Min          875 non-null float64
# Salary_Max          875 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 80.1+ KB

# %%
jobs.describe()
# Out:
#           Salary_Min     Salary_Max
# count     875.000000     875.000000
# mean     9423.897143   14646.446857
# std     24692.445188   34250.884169
# min      1800.000000    2000.000000
# 25%      4000.000000    6000.000000
# 50%      5000.000000    8000.000000
# 75%      7000.000000   11700.000000
# max    380000.000000  405000.000000

# %% [markdown]
# #### It's clear from the table above there are some unusual salary numbers in the mix. AspenTech, for instance, is offering a salary of SGD380,000 to SGD405,000. A check on the jobs portal shows that the figure is indeed an annual renumeration [https://www.mycareersfuture.sg/job/vp-sales-aspentech-dbe12dc833aac79f3ccccb02c491b983]
#
# #### Further checks show that these companies are using annual renumeration, which would have to be changed to monthly renumeration:
# - DataRobot
# - ONECONNECT FINANCIAL TECHNOLOGY
# - CISCO SYSTEMS
# - MICROSOFT OPERATIONS
# - RECORDED FUTURE PTE. LTD
# - SYNECHRON TECHNOLOGIES SINGAPORE PTE. LTD
# - AUTODESK ASIA
# - HILTON INTERNATIONAL ASIA PACIFIC PTE LTD
# - BEATHCHAPMAN (PTE. LTD.)
# - PURE STORAGE SINGAPORE PTE. LIMITED
# - FIREVISOR SYSTEMS PTE. LTD.
# - FOURTH PARADIGM SOUTHEAST ASIA PTE. LTD
# - NATIONAL UNIVERSITY OF SINGAPORE
# - ASPENTECH PTE. LTD
# - S.W.I.F.T. TERMINAL SERVICES PTE. LTD.
# - UNDERWRITEME TECHNOLOGY SOLUTIONS LIMITED SINGAPORE BRANCH
# - MERCER HEALTH & BENEFITS (SINGAPORE) PTE. LTD
# - VISA WORLDWIDE PTE. LIMITED
# - SABRE ASIA PACIFIC PTE. LTD
# - Company Undisclosed (one entry)

# %%
#As suspected, companies offering "minimum" salary of 30,000 dollars were giving annual renumeration
jobs[jobs['Salary_Min'] > 30000]
# Out:
#                                                Company  \
# 11                       DATAROBOT SINGAPORE PTE. LTD.
# 19                       DATAROBOT SINGAPORE PTE. LTD.
# 33   ONECONNECT FINANCIAL TECHNOLOGY (SINGAPORE) CO...
# 67                       CISCO SYSTEMS (USA) PTE. LTD.
# 104                      DATAROBOT SINGAPORE PTE. LTD.
# 106                      DATAROBOT SINGAPORE PTE. LTD.
# 108                      DATAROBOT SINGAPORE PTE. LTD.
# 148                       MICROSOFT OPERATIONS PTE LTD
# 149                          RECORDED FUTURE PTE. LTD.
# 157                      DATAROBOT SINGAPORE PTE. LTD.
# 162                      DATAROBOT SINGAPORE PTE. LTD.
# 253         SYNECHRON TECHNOLOGIES SINGAPORE PTE. LTD.
# 374     MERCER HEALTH & BENEFITS (SINGAPORE) PTE. LTD.
# 426                            AUTODESK ASIA PTE. LTD.
# 501                                Company Undisclosed
# 517          HILTON INTERNATIONAL ASIA PACIFIC PTE LTD
# 560                           BEATHCHAPMAN (PTE. LTD.)
# 700                      DATAROBOT SINGAPORE PTE. LTD.
# 701                      DATAROBOT SINGAPORE PTE. LTD.
# 723                PURE STORAGE SINGAPORE PTE. LIMITED
# 743                        FIREVISOR SYSTEMS PTE. LTD.
# 753           FOURTH PARADIGM SOUTHEAST ASIA PTE. LTD.
# 797                   NATIONAL UNIVERSITY OF SINGAPORE
# 870                                ASPENTECH PTE. LTD.
# 871                                ASPENTECH PTE. LTD.
# 898                        VISA WORLDWIDE PTE. LIMITED
# 909         SYNECHRON TECHNOLOGIES SINGAPORE PTE. LTD.
# 913                      DATAROBOT SINGAPORE PTE. LTD.
# 943                       SABRE ASIA PACIFIC PTE. LTD.
# 957             S.W.I.F.T. TERMINAL SERVICES PTE. LTD.
# 960  UNDERWRITEME TECHNOLOGY SOLUTIONS LIMITED SING...
# 966                        VISA WORLDWIDE PTE. LIMITED
#
#                                                  Title  \
# 11                      Applied Data Science Associate
# 19                         Data Scientist, AI Services
# 33   Intelligent Risk Data Scientist Manager / Assi...
# 67                               Senior Data Scientist
# 104  Business Intelligence Analyst - Machine Engine...
# 106                            Senior Backend Engineer
# 108                                   Quality Engineer
# 148                           Business Program Manager
# 149                 Director of Sales Engineering, APJ
# 157                          Software Engineer in Test
# 162                              Data Science Engineer
# 253                       Senior Technology Specialist
# 374             Health and Benefits Consulting Analyst
# 426                  19WD32806_SAP ABAP / HANA Develop
# 501                            Chief Financial Officer
# 517  Manager, Digital and Marketing Analytics - Asi...
# 560                                      Data Engineer
# 700        Sales Development Representative (Japanese)
# 701          Sales Development Representative (Korean)
# 723                    Digital Marketing Manager - APJ
# 743                                 Software Developer
# 753           FPGA Application Developer (AI Platform)
# 797                                    Research Fellow
# 870               Senior Principal Business Consultant
# 871                                          VP, Sales
# 898                                  Software Engineer
# 909                        Senior Full Stack Developer
# 913             Software Engineer, Machine Engineering
# 943                    Associate Incentives Accounting
# 957                     MANAGERIAL / SENIOR MANAGEMENT
# 960                                         BI Analyst
# 966                                   Systems Engineer
#
#                                       Responsibilities  \
# 11   Roles & ResponsibilitiesLooking to move into D...
# 19   Roles & ResponsibilitiesAI Services is a consu...
# 33   Roles & Responsibilities Develop AI Algorithm,...
# 67   Roles & Responsibilities    What You'll Do As ...
# 104  Roles & ResponsibilitiesWe are building a comp...
# 106  Roles & ResponsibilitiesDataRobot accelerates ...
# 108  Roles & ResponsibilitiesDataRobot changes the ...
# 148  Roles & ResponsibilitiesMicrosoft’s HIT team e...
# 149  Roles & ResponsibilitiesWant to be part of sha...
# 157  Roles & ResponsibilitiesThis position’s respon...
# 162  Roles & ResponsibilitiesAs a Data Science Engi...
# 253  Roles & ResponsibilitiesSynechron on behalf of...
# 374  Roles & ResponsibilitiesA global and prominent...
# 426  Roles & ResponsibilitiesDo what’s next Would y...
# 501  Roles & ResponsibilitiesThe Chief Financial Of...
# 517  Roles & ResponsibilitiesThe Analytics Team ser...
# 560  Roles & Responsibilities•   Leading online tra...
# 700  Roles & ResponsibilitiesAs a Sales Development...
# 701  Roles & ResponsibilitiesAs a Sales Development...
# 723  Roles & ResponsibilitiesAbout Us Our ambitious...
# 743  Roles & ResponsibilitiesHIGHLIGHTS:  Join our ...
# 753  Roles & ResponsibilitiesFPGA Application Devel...
# 797  Roles & ResponsibilitiesWe are looking for a h...
# 870  Roles & ResponsibilitiesAspenTech is a leading...
# 871  Roles & ResponsibilitiesAspenTech is a leading...
# 898  Roles & ResponsibilitiesCompany Description As...
# 909  Roles & ResponsibilitiesSynechron, one of the ...
# 913  Roles & ResponsibilitiesAt DataRobot, we are p...
# 943  Roles & ResponsibilitiesSabre is a technology ...
# 957  Roles & ResponsibilitiesJob Title: Senior Prod...
# 960  Roles & Responsibilities The role will be expe...
# 966  Roles & ResponsibilitiesCompany Description As...
#
#                                           Requirements  \
# 11   RequirementsMain Requirements  Experience/Trai...
# 19   RequirementsMain Requirements * 3+ years of re...
# 33   Requirements More than 5 years (10 years for S...
# 67   RequirementsWho You Are Do you thrive in a mul...
# 104  RequirementsRequirements  3+ years of experien...
# 106  RequirementsMain Requirements:  3+ years devel...
# 108  Requirements 3+ years of professional quality ...
# 148  RequirementsQualifications   Behaviour and cha...
# 149  RequirementsQualifications  Minimum of 3-5 yea...
# 157  RequirementsSkills:  Solid foundation in quali...
# 162  Requirements 5+ years of combined python Engin...
# 253  RequirementsThe senior Technology specialist i...
# 374  Requirements· Global and Regional account mana...
# 426  RequirementsTechnical Skills  Bachelor's degre...
# 501  RequirementsA Bachelor’s degree in Accounting,...
# 517  RequirementsWhat are we looking for? A Manager...
# 560  RequirementsOn behalf of our client, BeathChap...
# 700  RequirementsExperience Required  2+ years of c...
# 701  RequirementsExperience Required  2+ years of c...
# 723  RequirementsWhat You Bring To The Team  Proven...
# 743  RequirementsABOUT YOU:   You have 2+ years of ...
# 753  RequirementsREQUIREMENT This role will take re...
# 797  Requirements PhD in Computational Biology, Com...
# 870  Requirements B.S. in Engineering with 10-15 ye...
# 871  Requirements Bachelor’s degree (Engineering/Te...
# 898  RequirementsQualifications So what are we look...
# 909  RequirementsSynechron are looking for a Full S...
# 913  RequirementsRequirements:  3+ years of experie...
# 943  RequirementsEDUCATION:  Bachelor's degree in A...
# 957  RequirementsResponsibilities: Your responsibil...
# 960  Requirements Information gathering for new and...
# 966  RequirementsQualifications  BS or MS in Comput...
#
#                                              Seniority       Employment_Type  \
# 11                                        Professional             Permanent
# 19                                        Professional             Permanent
# 33                                    Senior Executive  Permanent, Full Time
# 67                                        Professional             Full Time
# 104                                       Professional             Permanent
# 106                                       Professional             Permanent
# 108                                       Professional             Permanent
# 148                                      Non-executive             Full Time
# 149                                  Senior Management             Full Time
# 157                                       Professional             Permanent
# 162                                       Professional             Permanent
# 253                              Manager, Professional             Full Time
# 374                                  Fresh/entry level             Permanent
# 426                                       Professional  Permanent, Full Time
# 501                                  Senior Management             Permanent
# 517                                            Manager  Permanent, Full Time
# 560                                            Manager             Permanent
# 700                                       Professional             Permanent
# 701                                       Professional             Permanent
# 723                                            Manager             Full Time
# 743                    Non-executive, Junior Executive             Full Time
# 753                                       Professional             Permanent
# 797                                      Non-executive             Full Time
# 870                                       Professional  Permanent, Full Time
# 871                                  Senior Management  Permanent, Full Time
# 898                                  Fresh/entry level  Permanent, Full Time
# 909  Middle Management, Professional, Executive, Se...             Full Time
# 913                                       Professional             Permanent
# 943                                          Executive             Full Time
# 957                         Senior Management, Manager             Permanent
# 960                                       Professional             Permanent
# 966                                  Fresh/entry level  Permanent, Full Time
#
#                              Category  \
# 11             Information Technology
# 19             Information Technology
# 33             Information Technology
# 67             Information Technology
# 104            Information Technology
# 106            Information Technology
# 108            Information Technology
# 148            Information Technology
# 149            Information Technology
# 157            Information Technology
# 162            Information Technology
# 253               Banking and Finance
# 374                       Consulting
# 426            Information Technology
# 501  Accounting / Auditing / Taxation
# 517     Marketing / Public Relations
# 560            Information Technology
# 700            Information Technology
# 701            Information Technology
# 723     Marketing / Public Relations
# 743                       Engineering
# 753            Information Technology
# 797                            Others
# 870                       Consulting
# 871                            Others
# 898            Information Technology
# 909            Information Technology
# 913            Information Technology
# 943  Accounting / Auditing / Taxation
# 957               Banking and Finance
# 960                         Insurance
# 966            Information Technology
#
#                                                Address  Salary_Min  Salary_Max
# 11                             80 ROBINSON ROAD 068898     90000.0    150000.0
# 19                             80 ROBINSON ROAD 068898     90000.0    150000.0
# 33                                         Undisclosed     96000.0    120000.0
# 67     ONE MARINA BOULEVARD, 1 MARINA BOULEVARD 018989    170000.0    230000.0
# 104                            80 ROBINSON ROAD 068898     90000.0    150000.0
# 106                            80 ROBINSON ROAD 068898     90000.0    150000.0
# 108                            80 ROBINSON ROAD 068898     90000.0    150000.0
# 148                                        Undisclosed     90000.0    135000.0
# 149                                        Undisclosed    180000.0    190000.0
# 157                            80 ROBINSON ROAD 068898    100000.0    120000.0
# 162                            80 ROBINSON ROAD 068898     90000.0    150000.0
# 253          ONE RAFFLES PLACE, 1 RAFFLES PLACE 048616    120000.0    240000.0
# 374          ASIA SQUARE TOWER 1, 8 MARINA VIEW 018960     45000.0     75000.0
# 426               SYMBIOSIS, 3 FUSIONOPOLIS WAY 138633     60900.0    121800.0
# 501                                        Undisclosed    380000.0    400000.0
# 517          CENTENNIAL TOWER, 3 TEMASEK AVENUE 039190     80000.0    150000.0
# 560                                        Undisclosed    120000.0    140000.0
# 700                            80 ROBINSON ROAD 068898     40000.0     60000.0
# 701                            80 ROBINSON ROAD 068898     40000.0     60000.0
# 723                     100 AM, 100 TRAS STREET 079027    158000.0    237000.0
# 743                         32 CARPENTER STREET 059911     60000.0     80000.0
# 753  MARINA BAY FINANCIAL CENTRE, 12 MARINA BOULEVA...    120000.0    250000.0
# 797                    21 LOWER KENT RIDGE ROAD 119077     58560.0    117120.0
# 870               GALAXIS, 1 FUSIONOPOLIS PLACE 138522    140000.0    207000.0
# 871               GALAXIS, 1 FUSIONOPOLIS PLACE 138522    280000.0    405000.0
# 898                                        Undisclosed     50000.0     65000.0
# 909          ONE RAFFLES PLACE, 1 RAFFLES PLACE 048616     70000.0    140000.0
# 913                            80 ROBINSON ROAD 068898     90000.0    150000.0
# 943          ABACUS PLAZA, 3 TAMPINES CENTRAL 1 529540     34700.0     64500.0
# 957                            80 ROBINSON ROAD 068898    275000.0    330000.0
# 960                                        Undisclosed    120000.0    160000.0
# 966                                        Undisclosed     50000.0     65000.0

# %%
# Converting min salaries from annual renumeration to monthly figures
jobs['Salary_Min'] = jobs.apply(lambda row: row['Salary_Min']/12
                                if row['Salary_Min'] > 30000
                                else row['Salary_Min'],
                                axis= 1)

# %%
# Converting max salaries from annual renumeration to monthly figures
jobs['Salary_Max'] = jobs.apply(lambda row: row['Salary_Max']/12
                                if row['Salary_Max'] > 30000
                                else row['Salary_Max'],
                                axis= 1)

# %%
# Creating an average salary column for easier comparison during modelling 
jobs['Salary_Average'] = (jobs['Salary_Min'] + jobs['Salary_Max'])/2
jobs['Salary_Average'] = jobs['Salary_Average'].round(1)

# %% [markdown]
# #### 1.3 IMPUTING MISSING SALARY FIGURES

# %%
jobs.describe()
# Out:
#          Salary_Min    Salary_Max  Salary_Average
# count    875.000000    875.000000      875.000000
# mean    5685.824762   8866.292571     7276.058857
# std     2822.930481   4256.999466     3454.453739
# min     1800.000000   2000.000000     1900.000000
# 25%     4000.000000   6000.000000     4750.000000
# 50%     5000.000000   8000.000000     6500.000000
# 75%     7000.000000  11300.000000     9000.000000
# max    31666.666667  33750.000000    32500.000000

# %% [markdown]
# #### The salary numbers now look more in line with what we know about the Singapore job market and the salary expectations in the data industry here. There are still some outliers, as we can see from the max salary figures above. As such, I would use the median instead to impute the missing salary figures.

# %%
jobs['Salary_Min'] = jobs['Salary_Min'].fillna(5000)
jobs['Salary_Max'] = jobs['Salary_Max'].fillna(8000)
jobs['Salary_Average'] = jobs['Salary_Average'].fillna(6500)

# %% [markdown]
# #### 1.4 REMOVE REPETITIVE WORDS SCOOPED UP DURING SCRAPPING
# The web scrapping repeatedly picked up words like "Roles & Responsibilities" and "PTE. LTD." which won't be useful in the analysis. Let's get rid of them ahead of the modelling.

# %%
jobs['Responsibilities'] = jobs['Responsibilities'].str.replace('Roles & Responsibilities', '')

# %%
jobs['Requirements'] = jobs['Requirements'].str.replace('Requirements', '')

# %%
jobs['Company'] = jobs['Company'].str.replace('PTE. LTD.', '')
jobs['Company'] = jobs['Company'].str.replace('PTE LTD', '')
jobs['Company'] = jobs['Company'].str.replace('PRIVATE LIMITED', '')
jobs['Company'] = jobs['Company'].str.replace('LIMITED', '')
jobs['Company'] = jobs['Company'].str.replace('PTE.', '')
jobs['Company'] = jobs['Company'].str.replace('LTD.', '')

# %% [markdown]
# #### 1.5 DELETING ON UNSUITABLE ROWS PICKED UP DURING SCRAPING
# Web-scraping is not always precise. Combined with the broad-nature of data science jobs and the general vagueness which some companies approach their job postings, it's no surprise that a check on the job title alone throws up some entries which clearly don't meet the criteria for this project.

# %%
jobs['Title'].unique()
# Out:
# array(['Senior Consultant (Data Scientist)', 'Data Science Lead',
#        'Senior Level Data Scientist', 'Mid - Senior Level Data Scientist',
#        'Mid Level Data Scientist', 'Data Scientist',
#        'Data Scientist (Project Manager)', 'Senior Data Scientist',
#        'Applied Data Science Associate', 'SENIOR DATA SCIENTIST',
#        'Business Data Scientist',
#        'AVP, Data Scientist, Analytics & Innovation, Group Legal, Compliance and Secretariat (WD03653)',
#        'Manager, Data and Analytics, Advisory',
#        'Data Scientist, AI Services',
#        'Sr Data Scientist (Exp in ML, Python, R and Bidata Tech is Must)',
#        'Data Engineer', 'Field Data Scientist',
#        'SVP, Big Data and Customer Experience Optimisation',
#        'Junior Data Scientist',
#        'Intelligent Risk Data Scientist Manager / Assistant Manager',
#        'Data Transformation Scientist', 'ETL Developer (ITSR)',
#        'Data Scientist Analyst', 'Lead Data Scientist',
#        'Assoc, Data Scientist (BAU) Operations Intelligence, CBG Ops, Technology and Operations (WD03348)',
#        'Data Scientist (Economist)', 'Presales Specialist - Data Science',
#        'Data Engineer (Ref 22998)', 'Vice President, Data Science',
#        'Senior Manager, Data Engineer', 'DATA Scientist',
#        'Data scientist',
#        'PI, Enterprise Intelligence (Data Scientist) Senior Manager (Financial Services), Advisory SG',
#        'Big Data Engineer', 'Junior Data Analyst',
#        'Scientist (Data Analytics), I2R / A*STAR',
#        'Data Engineer, Data Governance (1 Year Contract)',
#        'Fab10 Data Science Engineer / Data Scientist',
#        'Azure Data Analyst',
#        'VP, Data Scientist, Investment and Trading Technology, Technology and Operations (WD00504)',
#        'AVP, Data Scientist, Investment and Trading Technology, Technology and Operations (WD00504)',
#        'Data Scientist (Natural Language Processing)',
#        'Senior Data Platform Engineer',
#        'Data Scientist, Credit Risk - Visa Consulting & Analytics',
#        'Postdoctoral Fellow / Research Fellow (Data Analytics) / Data Scientist',
#        'Contract (Senior), Financial Crime Analytics – Internal & External Fraud, Group Compliance (WD00340)',
#        'Research Associate - Bioinformatics Analyst (Pathology)',
#        'Staff Software Engineer',
#        'SVP, Program Manager (Data Analytic), Institutional Banking Group Technology, T&O (WD03269)',
#        'Senior Data Analyst', 'Senior Hadoop Engineer', 'Research Fellow',
#        'NetSuite Administrator', 'Lecturer / Senior Lecturer',
#        'Business Intelligence Analyst - Machine Engineering',
#        'Associate Director, Enterprise Analytics',
#        'Senior Backend Engineer', 'Head Of Data Analytics',
#        'Quality Engineer',
#        'Research Fellow (1-year contract),\xa0 Living Analytics Research Centre',
#        'Research Associate - Bioinformatics Analyst',
#        'Pre-Doctoral Research Associate / Assistant',
#        'Associate, Data Engineer', 'Regional Sales Operations Lead, APAC',
#        'Data Science Analyst', 'PRODUCT MANAGER (DEX)',
#        'Full Stack Developer', 'Senior Research Fellow',
#        'Field Operation Engineer - Big Data Engineer',
#        'Senior Java Full Stack Developer',
#        'Research Scientist (1-year contract),\xa0 Living Analytics Research Centre',
#        'Associate / AVP, Research Engineer', 'Assistant Professor',
#        'Marketing Analytics Manager', 'Datawarehouse Engineer',
#        'Senior Research Scientist (1-year contract), Living Analytics Research Centre',
#        'Instructor in Interactive Media Design (Educator Track)',
#        'Channel Partner Recruitment Manager', 'APJ Media Manager',
#        'UX Researcher',
#        'Associate General Manager- Digital and Analytics',
#        'Data Engineer  /  Analyst', 'Information Technology  Specialist',
#        'Vice President, Enterprise Data Warehouse',
#        'Business Analyst, Customer and Digital Analytics',
#        'Business Program Manager', 'Director of Sales Engineering, APJ',
#        'Data Science Engineer', 'Data Science',
#        'People Analytics Lead, Senior Manager',
#        'Senior Manager  /  Director , Product Management',
#        'Senior / Data Engineer (Data Science Team)', 'Data Analyst, APAC',
#        'Business Integrity Associate, Technical',
#        'Software Engineer in Test',
#        'MCT Global Planning Mfg Data Science Engineer',
#        'SENIOR DATA ANALYST', 'Senior Machine Learning Engineer',
#        'Growth Marketer (Lifecycle)',
#        'Research Associate (Data Science) - EEE / INFINITUS',
#        'Research Engineer, IHPC', 'Scientist (CS), IHPC',
#        'Senior Scientist', 'Data Science Consulting',
#        'Marketing Science Partner', 'Product Designer',
#        'Program Director, IHPC', 'Project Manager', 'Software Engineer',
#        'Business Fraud Program Manager',
#        'Data Specialist (Recognition Services)', 'Research Associate',
#        'Project Officer', 'AVP / VP (Investment Services Public Markets)',
#        'Product Manager', 'Senior Technical Program Manager',
#        'Regional Head of Agent Marketing (Engagement)',
#        'SVP, Technical Delivery Manager, Middle Office Technology, Technology & Operations (WD02651)',
#        'VP, Technical Delivery Manager, Middle Office Technology, Technology & Operations (WD02651)',
#        'Mid Level Data Analyst', 'Platform Engineer',
#        'Data Analytics Lead', 'CRM Data Analyst',
#        'Technical Data Analyst', 'Data Analyst',
#        'Data Management Analyst-Operations (Financial Institution / Town)',
#        'Supply Chain Planning Anaylst', 'Data Analyst (Fairprice)',
#        'Business Analyst (NTUC First Campus, Data Analytics)',
#        'Analyst, Static Data Maintenance Specialist, SG-Wealth Mgmt Ops, T&O (WD03266)',
#        'Senior Business Data Analyst', 'Business Analyst (Data)',
#        'Data Planner', 'DATA ANALYST',
#        'Associate, Advisory Data and Analytics',
#        'Data Analyst (Vietnamese language proficient)',
#        'Data Analyst at Viki Inc', 'data analyst',
#        'HR Data Analyst / MNC / Central / 5 days week / 1 year contract',
#        'AVP, Senior Data Analyst, Middle Office Technology, Technology and Operations - (WD03337)',
#        'Senior Associate, Senior Data Analyst, Middle Office Technology, Technology and Operations-(WD03337)',
#        'Industrial Placement - Data Analytics and Support Analyst',
#        'Test Analyst', 'Data analyst', 'Data Analyst - Singapore',
#        'Junior - Mid Level Data Analyst',
#        'Data Analyst - Consumer Banking',
#        'Data Analyst, Google Pay - Singapore', 'Cloud and Data analyst',
#        'Operations Analyst - Reference Data Services',
#        'Junior Data Analyst - SQL (Training Program for 15th April to 14th Jan 2020)',
#        'Data Analyst, Data Management', 'Big Data Consultant',
#        '2019 Market Data Analyst', 'Sr Data Analyst',
#        'Data Analyst - Migration Coordinator', 'Data Analyst (Migration)',
#        'iTero Data and Reporting Analyst',
#        'Senior Project Manager, Analytics',
#        'Senior Technology Specialist', 'Lead Database Analyst',
#        'Data Visualisation Engineer (West)',
#        'Digital Marketing Executive', 'Finance & Control Director',
#        'Manager', 'management manager', 'Data Migration Manager',
#        'Director', 'Security Operations Center (SOC) Analyst',
#        'Senior Associate, Institutional Banking Group, GTS-SME Cash Commercialisation Specialist - (WD03694)',
#        'AVP, Institutional Banking Group, GTS-SME Cash Commercialisation Specialist - (WD03694)',
#        'IT Data & Analytics Manager (FP&A)',
#        'Senior Staff Technical Program Manager', 'HSE Consultant',
#        'CRM Manager', 'Logistic and Procurement Executive',
#        'Technical Project Manager', 'Human Resource Executive',
#        'Manager, Risk & Compliance',
#        'Senior Consultant – Life Insurance, non-life, reinsurance',
#        'Manager - Audit ( Data Analytics)',
#        'Human Resource & Administrative Officer', 'Senior Manager',
#        'Researcher (Intelligent Data Analytics)',
#        'Data Analytics Specialist',
#        'Senior Manager, Data and Analytics, Advisory',
#        'Asia Product Manager', 'Restaurant Manager',
#        'Manufacturing Software Engineer', 'Analyst',
#        'Cloud Database Admin', 'Project Analyst', 'Lead Project Manager',
#        'Director of Applications', 'Software Analyst',
#        'Research Engineer (Data Analytics), I2R (A*STAR)',
#        'Solution Architect',
#        'Research Engineer (Cyber Security&Intelligence), I2R / A*STAR',
#        'Research Engineer (Visual Intelligence), I2R / A*STAR',
#        'Strategic Marketing Analyst, Scalable Marketing Solutions - Singapore',
#        'Research Engineer (Human language Technologies) /  I2R (A*STAR)',
#        'Talent Acquisition Manager', 'HR and Admin Executive',
#        'Data ML Engineer', 'Manager (ECTD) /  I2R(A*STAR)',
#        'Scientist (Robotics & Autonomous Systems), I2R / A*STAR',
#        'DevOps Engineer', 'Back-end Engineer',
#        'Senior Solution Architect', 'Senior Enterprise Architect',
#        'VP, Enterprise Architect', 'VP, Credit Risk Review',
#        'Manager (Electronics)', 'Ethics Manager',
#        'data analytics manager', 'senior officer',
#        'Research Engineer (Deep Learning 2.0)  /  I2R (A*STAR)',
#        'Associate Analyst Mastercard Graduate Development Program',
#        'Environmental Manager  /  Assistant',
#        'Scientist (Deep Learning 2.0), I2R / A*STAR',
#        'IT Audit Manager  /  $7000 Basic + 2VB  /  CBD  /  Immediate !!!',
#        'Industry Development Manager, I2R / A*STAR',
#        'Software Development Consultant',
#        'Faculty Positions in Construction Automation - Civil Engineering',
#        'Senior Manager, Postgraduate Career Services (3-year contract), LKCSB',
#        'HR Practitioner', 'Account Manager', 'Lead  Analyst',
#        'Application Support Operations Specialist', 'Product Director',
#        'Operations & Maintenance Engineer',
#        'VP, Technology Auditor, Group Audit (190000UV)',
#        'AVP, Technology Auditor, Group Audit (190000UV)', 'Space Planner',
#        'Credit Risk Model Validation, AVP-VP',
#        'Senior /  Executive, Marketing Communications',
#        'Research Analyst', 'Business Operations and Marketing Executive',
#        'Customer Engineer, Data Analytics Specialist, Google Cloud - Singapore',
#        'SIS - Assistant Professor of Information Systems (Education / Practice), SCPS',
#        'Support Analyst', 'SEA Associate Account Manager, Media',
#        'Mobile Product Manager', 'Associate / AVP, Facilities Management',
#        'Audience Strategy Specialist',
#        'Digital Marketing Executive (Wedding Services Industry / Central Area / Up to 2.8K)',
#        'Account Manager (E-Commerce)', 'Development Engineer',
#        'Business Analyst', 'Manager / Senior Manager - Risk Advisory',
#        'Director  /  Senior Manager, Indirect Tax , APTC, Singapore',
#        'Health and Benefits Consulting Analyst', 'Lead Reseacher',
#        'Implementation Engineer', 'VP, Sales', 'Risk Assurance - Manager',
#        'Risk Assurance - Associate',
#        'IT Analyst (Fresh School Leaver are Welcome)',
#        'Risk Assurance - Assistant Manager',
#        'Business intelligence PMO Manager',
#        'Technology Risk Manager (Data Analytics), Advisory, Singapore',
#        'HR cum Admin Assistant [ Kallang Area, 5 Days, 1 Year Exp As HR]',
#        'RISK ASSURANCE - DATA & ANALYTICS ASSOCIATE', 'Deputy Director',
#        'Big data Presales',
#        'Senior Executive / Executive, Operations (Community Networks for Seniors)',
#        'HR & Admin Assistant', 'SENIOR ADMINISTRATIVE MANAGER',
#        'Assistant Manager',
#        'Senior Manager, System Operations (Ref 22991)',
#        'IT BUSINESS ANALYST', 'Management Consultant - Technology',
#        'Deputy General Manager', 'Strategic Director',
#        'Associate Director, Business Intelligence and Investigations',
#        'Senior Strategy Director',
#        'Recruitment Consultant - Technology ( Cyber Security)',
#        'Manager, Mechanical',
#        'Assistant Director (Data Analytics) (JD#5030)',
#        'Operations, Securities Division Operations, Equities Trading Services, Analyst',
#        'Operations, Reg & Control Ops, Regulatory Ops - Derivatives Regulatory Reporting - Associate (51814)',
#        'Operations, Regulatory Operations - Derivatives Regulatory Reporting - Executive Director  (51290)',
#        'Marketing Executive', 'HR Executive', 'HR OFFICER',
#        'Events Sales Manager',
#        'Principal Research Engineer (Human Language Technologies), I2R / A*STAR',
#        'Manager /  Senior Manager', '19WD32806_SAP ABAP / HANA Develop',
#        'Scientist (Human Language Technologies, I2R / A*STAR)',
#        'Software Engineer (Analytics, Big Data)', 'IT Quant',
#        'Market Analyst', 'Platform Delivery Lead',
#        'Senior Software Developer', 'DATA SCIENTISTS',
#        'Operations, Securities Division Operations, Equities Trading Services Operations, Associate (51430)',
#        'Front-End Developer', 'Senior Manager to Director',
#        'Data Analytics – IT Supply Chain',
#        'CIB - Neovest Account Manager — Market Data & Analytics Services – Vice President',
#        'Research Engineer (Data Analytics)',
#        'VP / Dir - Head of Service Transformation', 'Sales Executive',
#        'Finance and Admin Executive', 'IT Business Analysts',
#        'Business Analyst - Factory Integration',
#        'Engineering Manager - Transport', 'SAP Consultant (SD Module)',
#        'Supplier Quality Management Assistant Manager',
#        'Senior Manager - Data Analytics (Content)',
#        'VP, Senior Data Engineer Consultant, CBG and Big Data Analytics Technology, T&O (1800059H)',
#        'AVP, Senior Data Engineer Consultant, CBG and Big Data Analytics Technology, T&O (1800059H)',
#        'Digital Strategy Executive', 'IT Technical Manager',
#        'Program Advisor', 'Financial Consultant',
#        'Principal / Senior Engineer (Data Analytics & AI)',
#        'Scientific Director (Ref: IRG_2019_001)',
#        'Research Assistant / Research Associate / Postdoctoral Fellow / Research Fellow',
#        'Big Data Solution Architect', 'Client Service Outbound Executive',
#        'Enterprise Data Architect', 'Lead Solution Architect',
#        'Regional Expansion Manager',
#        'Senior Executive / Executive, System',
#        'Senior / Business Analyst', 'FP&A Controller',
#        'Sales Operations Executive - AP Cloud',
#        'Channel Insights Manager',
#        'Business Analytics & Insights – Retail Bank Segments & Sales Distribution',
#        'Principal Analyst - Digital Retail System', 'Product Analyst',
#        'Analytics Business Development Manager / Senior Manager',
#        'Sales Operations Specialist', 'Business Analytics Specialist',
#        'Chief Financial Officer',
#        'Head of Business Intelligence and Analytics',
#        'AVP, Investment Advisory – Business Infrastructure and Strategy, Private Banking (WD02311)',
#        'Assistant Vice President, E-commerce',
#        'Analyst /  Senior Analyst',
#        'AP Senior Sales Operation Executive - Cloud',
#        'SENIOR FINANCIAL ANALYST',
#        'Sales Operations and Business Analysis Executive',
#        'FP & A Manager',
#        'Analyst, Financial Crime Analytics – Transaction Surveillance, Group Compliance - (WD03638)',
#        'Financial Planning & Analytics Analyst',
#        '2019 Financial Product Analytics & Sales Graduate Program - Indonesian / Japanese / Thai Speakers',
#        'VP, Financial Crime Analytics – Transaction Monitoring, Group Compliance (WD02882)',
#        'AVP, Financial Crime Analytics – Transaction Monitoring, Group Compliance (WD02882)',
#        'Senior Lecturer, University',
#        'Manager, Digital and Marketing Analytics - Asia Pacific',
#        'Manager  /  Senior Manager Regional Marketing',
#        'Head of Marketing and Digital Product Analytics',
#        'Manager  /  Senior Manager, Regional Marketing (GrabWheels)',
#        'Regional Marketing Manager', 'Marketing Analytics Consultant',
#        'Manager, Marketing Analytics',
#        'Junior Analyst, Marketing Business Intelligence',
#        'Marketing Manager',
#        'Admin Assistant, Research Department (6 months contract)',
#        'Data Visualisation Developer', 'Lecturer', 'Senior Lecturer',
#        'Senior Associate', 'Information System Manager',
#        'IT Security Manager  (Central Area- Permanent Role)',
#        'Data Center Engineer (Operations)',
#        'Data Operations - Asset Management',
#        'Officer, Change Support, Reference Data Services Operations',
#        'Data Center Operations Engineer',
#        'Executive, Data Centre Operations',
#        'Associate, Data Engineer, Consumer Banking, Technology and Operations (WD03017)',
#        'VP, CAP Data Engineer, Middle Office Tech, Technology & Operations (WD02988)',
#        'Attractive L2 Support Engineer(Data Center Operations) opening in Singapore',
#        'Content Analyst', 'Data Strategist',
#        'Data Engineer (5 days, Orchard, $3500-4000)',
#        'Data Center Support Engineer', 'Data Engineer (Ref 22360)',
#        'Senior Level Data Engineer', 'Data Centre Engineer',
#        'Mid - Senior Level Data Engineer', 'Mid Level Data Engineer',
#        'Junior - Mid Level Data Engineer', 'Data  /  DevOps Engineer',
#        'Senior Database Consultant - Big Data Engineer',
#        'Data Governance Engineer', 'Data Analysis Engineer',
#        'Technical Services Engineer (Technical Data Management)',
#        'Senior Data Center Engineer',
#        'Big Data (HIVE) Engineer – 12 Months Renewable Contract',
#        'Assistant /  Engineer – Data Generation',
#        'Data Engineer (1 year contract)', 'Software Engineer (Big Data)',
#        'Senior Data Engineer', 'Data Center Engineer (Facility)',
#        'Senior Systems Engineer – Data Architecture',
#        'AVP, Network Engineer (Data & Security), Chief Technology Organization',
#        'Data Centre FM Engineer', 'Data Engineer  - Exasol',
#        'Data Technical Support Engineer', 'Web Application Developer',
#        'Big Data DevOps Engineer',
#        'Senior Engineer, Data Loss Protection',
#        'Voice / Data / Communication System Engineer', 'DATA ENGINEER',
#        'Lead Data Engineer - Business Intelligence',
#        'Software Engineer (Data Analysis)',
#        'Technical Lead - Big Data, Hadoop', 'Lead Big Data Engineer',
#        'Data Integration Architect', 'Data Statistician',
#        'SOLUTION ARCHITECT : EDW, BI & Data Integration',
#        'Big Data Architect', 'Senior SAP Consultant', 'Data Architect',
#        'AVP, Data Architect - Metadata Management, DBS Transformation Group, T&O (WD00640)',
#        'VP, Data Architect - Metadata Management, DBS Transformation Group, T&O (WD00640)',
#        'Data Architect, Vice President',
#        'Hiring for Solution Architect- Product Master Data Management',
#        'Senior Data Architect', 'Exasol Architect',
#        'Data Solution Director', 'BI / Data Architect',
#        'Manager, Clinical Data Management', 'Data Manager (Central Lab)',
#        'Assistant Manager, Data Steward for Substantial Shareholding Reporting',
#        'Optimisation Specialist',
#        'Manager for Process, Systems & Data Management, APAC',
#        'Data Center Facilities Manager - Singapore',
#        'SAP Data Migration Junior Project Manager',
#        'Data Partnership Manager - Group Lifestyle Financing',
#        'Data Processing Executive', 'Data Product Manager',
#        'IRIS Asia Pricing Master Data and BI - Development Manager',
#        'Senior Data Architecture Manager',
#        'Project Manager- Data Security', 'Data Solution Manager',
#        'Senior Manager - Data Governance & Controls (JD#5029)',
#        'ID Administrator',
#        'Electrical Manager (Data Centre / Construction)',
#        'Facilities Manager, Data Centre',
#        'Data Entry cum Admin Assistant',
#        'Enterprise Data Management - Market Data Manager',
#        'Enterprise Data Management - Data Governance & Valuations Manager',
#        'Enterprise Data Management - Data Steward',
#        'Senior Associate / Manager, Data Management',
#        'VP, Data Innovation Lead, UOB Asset Management',
#        'Data Engineering Lead',
#        'VP, Data Development Lead, Institutional Banking Group Technology, T&O (WD03261)',
#        'Data Migration Lead',
#        'VP, Data & Digital Strategic Transformation Lead, Improvement Program, T&O (WD02837)',
#        'Senior SAP® Data Migration Consultant',
#        'Pre-sales Consultant - Big Data (5 days, Orchard, $5000)',
#        'SAP Master Data Data Governance consultant',
#        'Consultant  /  Senior Consultant (Data Quality)',
#        'Data Integration Consultant', 'Consultant( Data Loss Prevention)',
#        'SAP Data Migration Consultant', 'Speech Algorithm Engineer',
#        'Software Developer', 'Development Lead', 'Full-Stack Developer',
#        'Security Researcher', 'Senior Front End Engineer',
#        'Advanced Technology Lab Head',
#        'Sales Development Representative (Japanese)',
#        'Sales Development Representative (Korean)',
#        'Project Manager, Systems Integration (3-year contract), Centre for Teaching Excellence',
#        'IT Manager', 'Research Assistant', 'Programme Coordinator',
#        'Senior Learning Designer', 'Cloud Operations Engineer',
#        'Machine Learning Developer', 'Backend Developer',
#        'Research Assistant (Artificial Intelligence)',
#        'senior software engineer', 'Digital Marketing Manager - APJ',
#        'Specialist, SSC Process & Projects',
#        'Manager, SSC Process & Projects', 'Sr. Cybersecurity Engineer',
#        'Visual Analytics Expert', 'Software Engineer - Team Lead',
#        'Consulting Analyst', 'Vice President, Machine Learning Engineer',
#        'Software Engineer (Image Processing)', 'Senior Software Engineer',
#        'Senior Java Developer', 'Emerging Technology Lead', 'Architect',
#        'Lead Product Manager', 'Senior Designer', 'Senior Engineer',
#        'FPGA Application Developer (AI Platform)',
#        'Machine Learning Algorithm Engineer / Senior Engineer',
#        'Engineering Lead', 'Fintech Lab Full-stack Developer',
#        'Unskippable Labs Experimentation Lead - Singapore',
#        'Research Engineer / Senior Research Engineer (ARTC)',
#        'Java Robotics Developer', 'Research Scientist, IHPC',
#        'Creative Strategist, Unskippable Labs - Singapore',
#        'Abuse Analyst, Real Time Communications - Singapore',
#        '2019 Full Time Campus Analyst - Engineering Division',
#        'Research Scientist', 'Scrum Master - Cybersecurity',
#        'Applied Research Engineer, Computer Vision and Deep Learning',
#        'IT Support Specialist',
#        'Research Fellow (Fintech Information Systems)',
#        'Research Assistant (Fintech Information Systems)',
#        'GIS - Research Officer (Computational Phenomics Platform)',
#        'AI Infrastructure Engineer for 100E (AISG)',
#        'Head of Digital Marketing',
#        'Regional Business Development Manager',
#        'Senior Research Assistant',
#        'Research Fellow, Acoustic Research Laboratory',
#        'AVP, Cloud Engineer, Investment & Trading Technology, Technology & Operations (WD00503)',
#        'Senior Assoc, Cloud Engineer, Investment & Trading Technology, Technology & Operations (WD00503)',
#        'Machine Learning Engineer', 'Lead Business Intelligence Analyst',
#        'Enforcement Detection Analyst, Trust and Safety, YouTube - Singapor',
#        'Software Engineer, Engineering Productivity',
#        'Application Developer',
#        'Junior Computer Vision Engineer for Deep learning applied to Real World Robotic System',
#        'Deep learning and Computer vision engineer',
#        'Consumer & Marketing Insights Analyst (Neuroscience Practices and Analysis)',
#        'Senior Engineer (Deep Learning) (Ref 23007)',
#        'Senior Engineer (Video Analytics)',
#        'Research Scientist(Low power ASIC for in-memory computation), IME',
#        'Content Marketing Executive', 'Key Executive Officer',
#        'Key Account Manager ($3500 – 5500, 5 Days, River Valley)',
#        'software engineer', 'Sr. Systems Engineer',
#        'Data Engineers ( Renewable Contract Roles )', 'Researcher',
#        'Senior Application Designer - Lead / Senior UX Designer',
#        'Sales Manager', 'Big Data Developer',
#        'People soft ERP Finance Technical Consultant',
#        'People Soft ERP Finance Functional Consultant',
#        'Data Governance Officer', 'Business Insights Analyst',
#        'Senior Associate, PCF Developer, Middle Office Technology, Technology and Operations (WD02453)',
#        'Infrastructure Engineer - Junior DevOps',
#        'Splunk Pre-sales Consultant (5 days, Orchard, $5000)',
#        'Key Account Manager - IT solutions ($3500 – 5500, 5 Days, River Valley)',
#        'Commercial Manager', 'Java Full Stack Developer', 'EDW Tester',
#        'Technical Architect', 'Senior Developer  /  Project Manager',
#        'Vice President, Window Security Administrator',
#        'Postdoctoral Associate / Research Scientist - Behavioral Modeling (Ref: IRG_FM_2019_007)',
#        'Infrastructure Development - Big Data', 'Java Big Data Developer',
#        'Specialist, Business Operations COE',
#        'Application Developer - Full Stack Developer',
#        'Customer Sustainability Manager', 'lead architect',
#        'Senior Principal Business Consultant', 'PowerBI Architect',
#        'Analytics End to End architect',
#        'Research Fellow (Bioinformatician, SIgN)',
#        'Technical Account Manager', 'Application Designer - UX Designer',
#        'Senior Developer (Big Data)',
#        'AVP,  QA Lead, Middle Office Technology, Technology and Operations (WD00414)',
#        'Senior Associate, QA Lead, Middle Office Technology, Technology and Operations (WD00414)',
#        'Postdoctoral Fellow', 'Regional Program Manager',
#        'AVP, PCF Developer, Middle Office Technology, Technology and Operations (180005CY)',
#        'Apps Dev Senior Programmer Analyst-18012492',
#        'UI / UX Designer for Big Data Dashboard Visualization',
#        'Senior Manager, Security Operations (Threat Hunter)',
#        'Vice President, Security Operations (Threat Hunter)',
#        'Application Engineer', 'Big Data Developer (Scala, Hadoop)',
#        'Senior Developer - Big Data', 'Senior Consultant',
#        'Business Intelligence', 'Business Intelligence Presales',
#        'Senior Controller, Asia Pacific', 'Senior Full Stack Developer',
#        'SAP Analytics Solutions Architect',
#        'Business Intelligence and Sales Operations Analyst',
#        'Business Intelligence Systems Business Analyst',
#        'Software Engineer, Machine Engineering', 'BI / ETL Developer',
#        'Associate Consultant', 'Reporting Analyst',
#        'IT Executive [$4.3k-$4.5k  /  Pioneer  /  SAP Business One  /  Networking  /  Hardware  /  5 days  /  Immediate]',
#        'Operations and Strategy Analyst', 'Power BI',
#        'Assistant Manager / Manager', 'BI Developer',
#        'IT Executive [$4.3k-$4.5k  /  Pioneer  /  SAP Business One  /  Networking  /  Hardware Support  /  Immediate]',
#        'Business Analyst - Business Intelligence (12 months contract)',
#        'Business Analyst  /  Central  /  Up to $5000+AWS+VB  /  SQL  /  Python',
#        'Financial Analyst (Associate)',
#        'Information Technology Executive', 'Application Analyst',
#        'DFS Strategy AAP',
#        'IT Support Executive [Pioneer  /  5 days  /  Hardware Support  /  Networking  /  SAP  /  Immediate]',
#        'Director, Sales',
#        'Software and Applications Developer and Analyst Nec',
#        'Senior Platform Engineer',
#        'Software Engineer - Competitive Pricing',
#        'Project Manager- Business Intelligence', 'Analytics Engineer',
#        'Associate Incentives Accounting',
#        'Technology Risk Associate (FAIT), Advisory, Singapore',
#        'Technology Risk Senior Associate (Financial Audit IT), Advisory, Singapore',
#        'Technology Risk Manager (Financial Audit IT), Advisory, Singapore',
#        'AX Technical Consultant', 'Deployment Project Manager',
#        'Procurement Business Intelligence (19001366)',
#        'Business Intelligence Analyst',
#        'MSBI Senior Business Intelligence Consultant',
#        'Business and Operations Manager, Google Cloud - Singapore',
#        'QLIK SENSE TECH LEAD', 'Consultant',
#        'Financial Controller, South East Asia',
#        'MANAGERIAL / SENIOR MANAGEMENT',
#        'IT Associate Business Analyst (Business Intelligence System)',
#        'Recruitment Consultant', 'BI Analyst',
#        'Executive  /  Senior Executive (Analytics)',
#        'Senior Datawarehouse Consultant',
#        'Regional Sales Force Effectiveness (SFE) Manager',
#        'Analytics Consultant', 'Systems Engineer',
#        'Integrated Knowledge Manager',
#        'Manager, International Marketplace',
#        'Finance Manager - Up to $7000', 'Data Management and Analysis',
#        'Business Solutions Manager'], dtype=object)

# %% [markdown]
# #### I'm deleting rows with the following job titles, as they clearly are not part of the data science industry:
# - 'Human Resource & Administrative Officer', 'HR cum Admin Assistant [ Kallang Area, 5 Days, 1 Year Exp As HR]', 'HR Practitioner'
# - 'Restaurant Manager'
# - 'Ethics Manager'
# - 'Account Manager'
# - 'IT Audit Manager  /  $7000 Basic + 2VB  /  CBD  /  Immediate !!!'
# - 'IT Executive [$4.3k-$4.5k  /  Pioneer  /  SAP Business One  /  Networking  /  Hardware  /  5 days  /  Immediate]'
# - 'Sales Executive', 'Sales Development Representative (Japanese)', 'Sales Development Representative (Korean)
# - 'Industry Development Manager, I2R / A*STAR'
# - 'Software Development Consultant'
# - 'Senior Java Developer',  'Java Robotics Developer'
# - 'Web Application Developer'
# - 'Data Entry cum Admin Assistant'
# - 'Faculty Positions in Construction Automation - Civil Engineering'
# - 'Senior Manager, Postgraduate Career Services (3-year contract), LKCSB'
# - 'Environmental Manager  /  Assistant' 'Space Planner'
# - 'Events Sales Manager'
# - 'Finance and Admin Executive'
# - 'Admin Assistant, Research Department (6 months contract)'
# - 'Vice President, Window Security Administrator', 'Financial Controller, South East Asia'

# %%
non_data = [
    "Human Resource & Administrative Officer",
    "HR cum Admin Assistant [ Kallang Area, 5 Days, 1 Year Exp As HR]",
    "Restaurant Manager",
    "Ethics Manager",
    "HR Practitioner",
    "Account Manager",
    "IT Audit Manager  /  $7000 Basic + 2VB  /  CBD  /  Immediate !!!",
    "Industry Development Manager, I2R / A*STAR",
    "Software Development Consultant",
    "Faculty Positions in Construction Automation - Civil Engineering",
    "Senior Manager, Postgraduate Career Services (3-year contract), LKCSB",
    "Environmental Manager  /  Assistant",
    "Space Planner",
    "Events Sales Manager",
    "Finance and Admin Executive",
    "Sales Executive",
    "Admin Assistant, Research Department (6 months contract)",
    "Web Application Developer",
    "Data Entry cum Admin Assistant",
    "Sales Development Representative (Japanese)",
    "Sales Development Representative (Korean)",
    "Senior Java Developer",
    "Java Robotics Developer",
    "Vice President, Window Security Administrator",
    "Financial Controller, South East Asia",
    "IT Executive [$4.3k-$4.5k  /  Pioneer  /  SAP Business One  /  Networking  /  Hardware  /  5 days  /  Immediate]",
]

# %%
jobs = jobs[~jobs['Title'].isin(non_data)]

# %%
jobs.shape
# Out:
# (905, 11)

# %% [markdown]
# #### I'm reasonably satisfied with the preliminary data cleaning, so I'll output it to a new file for visualisation and modelling.

# %%
#jobs_clean = jobs.to_csv('../data/jobs_clean.csv', index=False)

# %% [markdown]
# #### Data Viz for NLP-related projects tend to generate huge files, so I'll do that from a new notebook in 1.2
